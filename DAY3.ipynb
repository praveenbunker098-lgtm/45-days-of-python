# %% [markdown]
# <a href="https://colab.research.google.com/github/praveenbunker098-lgtm/45-days-of-python/blob/main/DAY3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # *Condition statement:*

# %% [markdown]
# 1.   if
# 2.   elif
# 3.   else

# %%
# if else
number = 5

if number % 2 == 0:
    print("Even")
else:
    print("Odd")
# if elif else

age = int(input("enter the number"))
if age == 18:
  print("your age is ",  age)
elif age >18:
  print("you are above then 18 < ", age)
else:
  print("you are less then 18 >" , age)

  #example 3

  marks = int(input("enter your marks"))
  if marks ==
# Out:
# Odd
# enter the number10
# you are less then 18 > 10

# %%
marks = int(input("enter your marks"))
if marks >= 90 :
  print("A")
elif marks >= 75:
  print("B")
elif marks >= 60:
  print("C")
else:
  print("failed")
# Out:
# enter your marks44
# failed

# %% [markdown]
# loops

# %%
for i in range(1,11):
  print("number ", i)
# Out:
# number  1
# number  2
# number  3
# number  4
# number  5
# number  6
# number  7
# number  8
# number  9
# number  10

# %%
num1 =  int(input("Enter the number :"))
i = 0
while i < num1:
  print(i)
  i += 1
# Out:
# Enter the number :5
# 0
# 1
# 2
# 3
# 4

# %%
l = [2,3,4,5,6]
i = 0

while i < len(l):
    print(l[i])
    i += 1
# Out:
# 2
# 3
# 4
# 5
# 6

# %%
l = [10, [11, 12, 13, 14]]

for i in range(len(l[1])):
    print(l[1][i])
# Out:
# 11
# 12
# 13
# 14

# %%
for i in range(5):
  if i == 2:
    break
  print(i)
# Out:
# 0
# 1

# %%
i = 0
while True:
  print(i)
  if i == 5:
    break
  else:
    i += 1
    continue
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# PASS KEYWORD

# %%
i = 0
while True:
  print(i)
  if i == 5:
    pass
  if i == 5:
    break
  else:
    i += 1
    continue
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
# 1. ATM Withdrawal System

balance = 10000

while True:
    amount = int(input("Enter withdrawal amount: "))

    if amount == 0:
        break

    if amount <= balance:
        balance -= amount
        print("Remaining Balance:", balance)
    else:
        print("Insufficient Balance")


# # 2. Student Result Analyzer

# passed = 0
# failed = 0

# for i in range(1, 6):
#     marks = int(input(f"Enter marks of student {i}: "))

#     if marks >= 40:
#         print("Pass")
#         passed += 1
#     else:
#         print("Fail")
#         failed += 1

# print("Total Passed:", passed)
# print("Total Failed:", failed)


# # 3. Password Retry System

# password = "python123"
# attempts = 0

# while attempts < 3:
#     user = input("Enter password: ")

#     if user == password:
#         print("Login Successful")
#         break
#     else:
#         print("Wrong Password")

#     attempts += 1

# if attempts == 3:
#     print("Account Locked")


# # 4. Electricity Bill Calculator

# for i in range(1, 4):
#     units = int(input(f"Enter units for customer {i}: "))

#     if units <= 100:
#         bill = units * 5
#     elif units <= 200:
#         bill = (100 * 5) + ((units - 100) * 7)
#     else:
#         bill = (100 * 5) + (100 * 7) + ((units - 200) * 10)

#     print("Bill Amount:", bill)


# # 5. Number Guessing Game

# secret = 25
# attempts = 0

# while True:
#     guess = int(input("Enter your guess: "))
#     attempts += 1

#     if guess > secret:
#         print("Too High")
#     elif guess < secret:
#         print("Too Low")
#     else:
#         print("Correct Guess")
#         print("Attempts:", attempts)
#         break
# Out:
# Remaining Balance: 8000
# Remaining Balance: 6000
